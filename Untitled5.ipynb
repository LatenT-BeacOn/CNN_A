# %% [markdown]
# <a href="https://colab.research.google.com/github/LatenT-BeacOn/CNN_A/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/LatenT-BeacOn/CNN_A.git
# %cd CNN_A
